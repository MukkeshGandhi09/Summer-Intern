# %%
import tensorflow as tf
import numpy as np
import cv2 
import os
import random


##Parameters required for the model##
data_path="data/"
height=100
width=100
all_classes = os.listdir(data_path)
number_of_classes = len(all_classes)
color_channels=3
epochs=10
batch_size=10
batch_counter=0
model_save_name="Model/"


images_ph=tf.placeholder(tf.float32,shape=[None,width,height,color_channels],name="input_image")
labels_ph=tf.placeholder(tf.float32,shape=[None,number_of_classes])
print("Initialised Completed")
# Out:
# Initialised Completed

# %% [markdown]
# ::::Model Architecture Defintions:::

# %%
  def add_weights(shape):
      return tf.Variable(tf.truncated_normal(shape=shape, stddev=0.05))

  def add_biases(shape):
      return tf.Variable(tf.constant(0.05, shape=shape))

  def conv_layer(layer, kernel, input_shape, output_shape, stride_size):
      weights = add_weights([kernel, kernel, input_shape, output_shape])
      biases = add_biases([output_shape])
      stride = [1, stride_size, stride_size, 1]
      layer = tf.nn.conv2d(layer, weights, strides=stride, padding='SAME') + biases
      return layer

  def pooling_layer(layer, kernel_size, stride_size):
      kernel = [1, kernel_size, kernel_size, 1]
      stride = [1, stride_size, stride_size, 1]
      return tf.nn.max_pool(layer, ksize=kernel, strides=stride, padding='SAME')

  def flattening_layer(layer):
      input_size = layer.get_shape().as_list()
      new_size = input_size[-1] * input_size[-2] * input_size[-3]
      return tf.reshape(layer, [-1, new_size]),new_size

  def fully_connected_layer(layer, input_shape, output_shape):
      weights = add_weights([input_shape, output_shape])
      biases = add_biases([output_shape])
      layer = tf.matmul(layer,weights) + biases
      return layer

  def activation_layer(layer):
      return tf.nn.relu(layer)

# %%
class utils:
    image_count = []
    count_buffer=[]
    class_buffer=all_classes[:]
    def __init__(self):
        self.image_count = []
        self.count_buffer = []
        for i in os.walk(data_path):
            if len(i[2]):
                self.image_count.append(len(i[2]))
        self.count_buffer=self.image_count[:]

    # processing images into arrays and dispatch as batches whenever called.
    def batch_dispatch(self,batch_size=batch_size):
        global batch_counter
        if sum(self.count_buffer):

            class_name = random.choice(self.class_buffer)
            choice_index = all_classes.index(class_name)
            choice_count = self.count_buffer[choice_index]
            if choice_count==0:
                class_name=all_classes[self.count_buffer.index(max(self.count_buffer))]
                choice_index = all_classes.index(class_name)
                choice_count = self.count_buffer[choice_index]

            slicer=batch_size if batch_size<choice_count else choice_count
            img_ind=self.image_count[choice_index]-choice_count
            indices=[img_ind,img_ind+slicer]
            images = self.generate_images(class_name,indices)
            labels = self.generate_labels(class_name,slicer)

            self.count_buffer[choice_index]=self.count_buffer[choice_index]-slicer
        else:
            images,labels=(None,)*2
        return images, labels

    #gives one hot for the respective labels
    def generate_labels(self,class_name,number_of_samples):
        one_hot_labels=[0]*number_of_classes
        one_hot_labels[all_classes.index(class_name)]=1
        one_hot_labels=[one_hot_labels]*number_of_samples
        #one_hot_labels=tf.one_hot(indices=[all_classes.index(class_name)]*number_of_samples,depth=number_of_classes)
        return one_hot_labels

    # image operations
    def generate_images(self,class_name,indices):
        batch_images=[]
        choice_folder=os.path.join(data_path,class_name)
        selected_images=os.listdir(choice_folder)[indices[0]:indices[1]]
        for image in selected_images:
            img=cv2.imread(os.path.join(choice_folder,image))
            batch_images.append(img)
        return batch_images

# %% [markdown]
# :::MODEL ARCHITECTURE:::

# %%
def model_generate():
  network=conv_layer(images_ph,5,3,16,1)
  network=pooling_layer(network,5,2)
  network=activation_layer(network)
  network=conv_layer(network,4,16,32,1)
  network=pooling_layer(network,4,2)
  network=activation_layer(network)
  network=conv_layer(network,3,32,64,1)
  network=pooling_layer(network,3,2)
  network=activation_layer(network)
  network,features=flattening_layer(network)
  network=fully_connected_layer(network,features,1024)
  network=activation_layer(network)
  network=fully_connected_layer(network,1024,2)
  return network

# %%
def trainer(network,no_of_images):
	print("\nTraining Started")
	cross_entropy=tf.nn.softmax_cross_entropy_with_logits_v2(logits=network,labels=labels_ph)
	cost=tf.reduce_mean(cross_entropy)
	tf.summary.scalar("cost", cost)

	optimizer=tf.train.AdamOptimizer().minimize(cost)
	#print(optimizer+"\n")
	with tf.Session() as sess:
		print("\nSession Initialised")
		sess.run(tf.global_variables_initializer())
		writer = tf.summary.FileWriter(model_save_name, graph=sess.graph)
		merged = tf.summary.merge_all()
		saver = tf.train.Saver(max_to_keep=4)
		counter=0
		for epoch in range(epochs):
			print("\n Epoch Started")
			tools = utils()
			for batch in range(int(number_of_images / batch_size)):
				print("\nBATCH Processeing started")
				counter+=1
				images, labels = tools.batch_dispatch()
				if images == None:
					break
			#	print("\nPRINTING ERROR")
				loss,summary = sess.run([cost,merged], feed_dict={images_ph: images, labels_ph: labels})
				print('loss', loss)
				sess.run(optimizer, feed_dict={images_ph: images, labels_ph: labels})
				print('Epoch number ', epoch, 'batch', batch, 'complete')
				writer.add_summary(summary,counter)
        model_saved=saver.save(sess,model_save_name)

# %%
#
network= model_generate()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
if __name__=="__main__":
	#global network
	print("\nMAIN FUNCTION HAS BEEN ENTERED")
	tools=utils()
  
	number_of_images = sum([len(files) for r, d, files in os.walk("data/")])
	trainer(network,number_of_images)
	print("\n---------------------------Training Over---------------------------")
# Out:
# MAIN FUNCTION HAS BEEN ENTERED
#
# Training Started
#
# Session Initialised
#
#  Epoch Started
#
# BATCH Processeing started
# loss 0.0
# Epoch number  0 batch 0 complete
#
# BATCH Processeing started
# loss 132.29016
# Epoch number  0 batch 1 complete
#
# BATCH Processeing started
# loss 2774.155
# Epoch number  0 batch 2 complete
#
# BATCH Processeing started
# loss 899.7585
# Epoch number  0 batch 3 complete
#
# BATCH Processeing started
# loss 0.0
# Epoch number  0 batch 4 complete
#
# BATCH Processeing started
# loss 97.313446
# Epoch number  0 batch 5 complete
#
# BATCH Processeing started
# loss 0.7080629
# Epoch number  0 batch 6 complete
#
# BATCH Processeing started
# loss 5.3344393
# Epoch number  0 batch 7 complete
#
# BATCH Processeing started
# loss 3.5478683
# Epoch number  0 batch 8 complete
#
# BATCH Processeing started
# loss 24.660492
# Epoch number  0 batch 9 complete
#
# BATCH Processeing started
# loss 1.3305584
# Epoch number  0 batch 10 complete
#
# BATCH Processeing started
# loss 3.42788
# Epoch number  0 batch 11 complete
#
# BATCH Processeing started
# loss 1.9293877
# Epoch number  0 batch 12 complete
#
# BATCH Processeing started
# loss 1.3113012e-07
# Epoch number  0 batch 13 complete
#
# BATCH Processeing started
# loss 42.87448
# Epoch number  0 batch 14 complete
#
# BATCH Processeing started
# loss 8.9238205
# Epoch number  0 batch 15 complete
#
# BATCH Processeing started
# loss 4.0908737
# Epoch number  0 batch 16 complete
#
# BATCH Processeing started
# loss 8.412806
# Epoch number  0 batch 17 complete
#
# BATCH Processeing started
# loss 0.0002941094
# Epoch number  0 batch 18 complete
#
# BATCH Processeing started
# loss 0.1548435
# Epoch number  0 batch 19 complete
#
# BATCH Processeing started
# loss 0.009410767
# Epoch number  0 batch 20 complete
#
# BATCH Processeing started
# loss 8.672459
# Epoch number  0 batch 21 complete
#
# BATCH Processeing started
# loss 0.0014589003
# Epoch number  0 batch 22 complete
#
# BATCH Processeing started
# loss 5.00423
# Epoch number  0 batch 23 complete
#
# BATCH Processeing started
# loss 2.7599626
# Epoch number  0 batch 24 complete
#
# BATCH Processeing started
# loss 0.051786035
# Epoch number  0 batch 25 complete
#
# BATCH Processeing started
# loss 5.5167866
# Epoch number  0 batch 26 complete
#
# BATCH Processeing started
# loss 2.5596328
# Epoch number  0 batch 27 complete
#
# BATCH Processeing started
# loss 1.5204046
# Epoch number  0 batch 28 complete
#
# BATCH Processeing started
# loss 0.37636995
# Epoch number  0 batch 29 complete
#
# BATCH Processeing started
# loss 0.3679407
# Epoch number  0 batch 30 complete
#
# BATCH Processeing started
# loss 7.394426
# Epoch number  0 batch 31 complete
#
# BATCH Processeing started
# loss 0.025729736
# Epoch number  0 batch 32 complete
#
# BATCH Processeing started
# loss 3.7821743
# Epoch number  0 batch 33 complete
#
# BATCH Processeing started
# loss 0.09647684
# Epoch number  0 batch 34 complete
#
# BATCH Processeing started
# loss 3.275004
# Epoch number  0 batch 35 complete
#
# BATCH Processeing started
# loss 0.2109245
# Epoch number  0 batch 36 complete
#
# BATCH Processeing started
# loss 1.8786972
# Epoch number  0 batch 37 complete
#
# BATCH Processeing started
# loss 0.9472853
# Epoch number  0 batch 38 complete
#
# BATCH Processeing started
# loss 0.5192257
# Epoch number  0 batch 39 complete
#
# BATCH Processeing started
# loss 0.2177668
# Epoch number  0 batch 40 complete
#
# BATCH Processeing started
# loss 0.32007524
# Epoch number  0 batch 41 complete
#
# BATCH Processeing started
# loss 1.0565002
# Epoch number  0 batch 42 complete
#
# BATCH Processeing started
# loss 1.2778708
# Epoch number  0 batch 43 complete
#
# BATCH Processeing started
# loss 2.8116963
# Epoch number  0 batch 44 complete
#
# BATCH Processeing started
# loss 0.11854313
# Epoch number  0 batch 45 complete
#
# BATCH Processeing started
# loss 0.0080435965
# Epoch number  0 batch 46 complete
#
# BATCH Processeing started
# loss 4.6017685
# Epoch number  0 batch 47 complete
#
# BATCH Processeing started
# loss 0.062329836
# Epoch number  0 batch 48 complete
#
# BATCH Processeing started
# loss 0.866718
# Epoch number  0 batch 49 complete
#
# BATCH Processeing started
# loss 0.69198716
# Epoch number  0 batch 50 complete
#
# BATCH Processeing started
# loss 0.5609016
# Epoch number  0 batch 51 complete
#
# BATCH Processeing started
# loss 0.5320167
# Epoch number  0 batch 52 complete
#
# BATCH Processeing started
# loss 0.30073586
# Epoch number  0 batch 53 complete
#
# BATCH Processeing started
# loss 0.26361006
# Epoch number  0 batch 54 complete
#
# BATCH Processeing started
# loss 0.093214415
# Epoch number  0 batch 55 complete
#
# BATCH Processeing started
# loss 2.7061388
# Epoch number  0 batch 56 complete
#
# BATCH Processeing started
# loss 5.0280123
# Epoch number  0 batch 57 complete
#
# BATCH Processeing started
# loss 1.8890823
# Epoch number  0 batch 58 complete
#
# BATCH Processeing started
# loss 0.81954
# Epoch number  0 batch 59 complete
#
# BATCH Processeing started
# loss 0.13566723
# Epoch number  0 batch 60 complete
#
# BATCH Processeing started
# loss 0.13762271
# Epoch number  0 batch 61 complete
#
# BATCH Processeing started
# loss 1.3891722
# Epoch number  0 batch 62 complete
#
# BATCH Processeing started
# loss 1.3568499
# Epoch number  0 batch 63 complete
#
# BATCH Processeing started
# loss 0.15219465
# Epoch number  0 batch 64 complete
#
# BATCH Processeing started
# loss 0.73735523
# Epoch number  0 batch 65 complete
#
# BATCH Processeing started
# loss 0.121234536
# Epoch number  0 batch 66 complete
#
# BATCH Processeing started
# loss 0.1522807
# Epoch number  0 batch 67 complete
#
# BATCH Processeing started
# loss 2.714995
# Epoch number  0 batch 68 complete
#
# BATCH Processeing started
# loss 0.114785716
# Epoch number  0 batch 69 complete
#
# BATCH Processeing started
# loss 0.25442785
# Epoch number  0 batch 70 complete
#
# BATCH Processeing started
# loss 0.97635764
# Epoch number  0 batch 71 complete
#
# BATCH Processeing started
# loss 0.33175868
# Epoch number  0 batch 72 complete
#
# BATCH Processeing started
# loss 0.13476196
# Epoch number  0 batch 73 complete
#
# BATCH Processeing started
# loss 0.30349466
# Epoch number  0 batch 74 complete
#
# BATCH Processeing started
# loss 0.06006985
# Epoch number  0 batch 75 complete
#
# BATCH Processeing started
# loss 0.13135277
# Epoch number  0 batch 76 complete
#
# BATCH Processeing started
# loss 0.022295529
# Epoch number  0 batch 77 complete
#
# BATCH Processeing started
# loss 0.026356217
# Epoch number  0 batch 78 complete
#
# BATCH Processeing started
# loss 0.022653019
# Epoch number  0 batch 79 complete
#
# BATCH Processeing started
# loss 6.458407
# Epoch number  0 batch 80 complete
#
# BATCH Processeing started
# loss 3.4028702
# Epoch number  0 batch 81 complete
#
# BATCH Processeing started
# loss 3.3861363
# Epoch number  0 batch 82 complete
#
# BATCH Processeing started
# loss 0.50041544
# Epoch number  0 batch 83 complete
#
# BATCH Processeing started
# loss 1.0491395
# Epoch number  0 batch 84 complete
#
# BATCH Processeing started
# loss 1.038196
# Epoch number  0 batch 85 complete
#
# BATCH Processeing started
# loss 1.152579
# Epoch number  0 batch 86 complete
#
# BATCH Processeing started
# loss 1.147538
# Epoch number  0 batch 87 complete
#
# BATCH Processeing started
# loss 0.31034315
# Epoch number  0 batch 88 complete
#
# BATCH Processeing started
# loss 1.4808502
# Epoch number  0 batch 89 complete
#
# BATCH Processeing started
# loss 0.3733365
# Epoch number  0 batch 90 complete
#
# BATCH Processeing started
# loss 1.760586
# Epoch number  0 batch 91 complete
#
# BATCH Processeing started
# loss 0.87020254
# Epoch number  0 batch 92 complete
#
# BATCH Processeing started
# loss 1.0237901
# Epoch number  0 batch 93 complete
#
# BATCH Processeing started
# loss 0.25881106
# Epoch number  0 batch 94 complete
#
# BATCH Processeing started
# loss 0.43769675
# Epoch number  0 batch 95 complete
#
# BATCH Processeing started
# loss 0.49456668
# Epoch number  0 batch 96 complete
#
# BATCH Processeing started
# loss 0.5354084
# Epoch number  0 batch 97 complete
#
# BATCH Processeing started
# loss 0.5467156
# Epoch number  0 batch 98 complete
#
# BATCH Processeing started
# loss 0.29783618
# Epoch number  0 batch 99 complete
#
# BATCH Processeing started
# loss 0.74342555
# Epoch number  0 batch 100 complete
#
# BATCH Processeing started
# loss 1.1538646
# Epoch number  0 batch 101 complete
#
# BATCH Processeing started
# loss 1.228739
# Epoch number  0 batch 102 complete
#
# BATCH Processeing started
# loss 0.51433176
# Epoch number  0 batch 103 complete
#
# BATCH Processeing started
# loss 0.70096755
# Epoch number  0 batch 104 complete
#
# BATCH Processeing started
# loss 0.40000844
# Epoch number  0 batch 105 complete
#
# BATCH Processeing started
# loss 1.0838246
# Epoch number  0 batch 106 complete
#
# BATCH Processeing started
# loss 0.543857
# Epoch number  0 batch 107 complete
#
# BATCH Processeing started
# loss 0.49125773
# Epoch number  0 batch 108 complete
#
# BATCH Processeing started
# loss 1.2046953
# Epoch number  0 batch 109 complete
#
# BATCH Processeing started
# loss 0.2771816
# Epoch number  0 batch 110 complete
#
# BATCH Processeing started
# loss 0.37033907
# Epoch number  0 batch 111 complete
#
# BATCH Processeing started
# loss 0.25545
# Epoch number  0 batch 112 complete
#
# BATCH Processeing started
# loss 0.6796975
# Epoch number  0 batch 113 complete
#
# BATCH Processeing started
# loss 0.24593803
# Epoch number  0 batch 114 complete
#
# BATCH Processeing started
# loss 0.7768034
# Epoch number  0 batch 115 complete
#
# BATCH Processeing started
# loss 0.34610075
# Epoch number  0 batch 116 complete
#
# BATCH Processeing started
# loss 1.189209
# Epoch number  0 batch 117 complete
#
# BATCH Processeing started
# loss 0.52009976
# Epoch number  0 batch 118 complete
#
# BATCH Processeing started
# loss 0.9159347
# Epoch number  0 batch 119 complete
#
# BATCH Processeing started
# loss 0.5265222
# Epoch number  0 batch 120 complete
#
# BATCH Processeing started
# loss 1.2308589
# Epoch number  0 batch 121 complete
#
# BATCH Processeing started
# loss 0.61321664
# Epoch number  0 batch 122 complete
#
# BATCH Processeing started
# loss 0.86706525
# Epoch number  0 batch 123 complete
#
# BATCH Processeing started
# loss 0.766711
# Epoch number  0 batch 124 complete
#
# BATCH Processeing started
# loss 0.36609086
# Epoch number  0 batch 125 complete
#
# BATCH Processeing started
# loss 0.69883096
# Epoch number  0 batch 126 complete
#
# BATCH Processeing started
# loss 0.85908926
# Epoch number  0 batch 127 complete
#
# BATCH Processeing started
# loss 0.26817855
# Epoch number  0 batch 128 complete
#
# BATCH Processeing started
# loss 1.8507025
# Epoch number  0 batch 129 complete
#
# BATCH Processeing started
# loss 0.37522554
# Epoch number  0 batch 130 complete
#
# BATCH Processeing started
# loss 0.37112367
# Epoch number  0 batch 131 complete
#
# BATCH Processeing started
# loss 1.4053589
# Epoch number  0 batch 132 complete
#
# BATCH Processeing started
# loss 1.0477636
# Epoch number  0 batch 133 complete
#
# BATCH Processeing started
# loss 0.6045615
# Epoch number  0 batch 134 complete
#
# BATCH Processeing started
# loss 0.7489459
# Epoch number  0 batch 135 complete
#
# BATCH Processeing started
# loss 0.4037532
# Epoch number  0 batch 136 complete
#
# BATCH Processeing started
# loss 0.54156756
# Epoch number  0 batch 137 complete
#
# BATCH Processeing started
# loss 0.6932569
# Epoch number  0 batch 138 complete
#
# BATCH Processeing started
# loss 0.70006526
# Epoch number  0 batch 139 complete
#
# BATCH Processeing started
# loss 0.5156276
# Epoch number  0 batch 140 complete
#
# BATCH Processeing started
# loss 0.44598848
# Epoch number  0 batch 141 complete
#
# BATCH Processeing started
# loss 0.5507563
# Epoch number  0 batch 142 complete
#
# BATCH Processeing started
# loss 0.8622395
# Epoch number  0 batch 143 complete
#
# BATCH Processeing started
# loss 1.4730713
# Epoch number  0 batch 144 complete
#
# BATCH Processeing started
# loss 0.9705536
# Epoch number  0 batch 145 complete
#
# BATCH Processeing started
# loss 0.25343758
# Epoch number  0 batch 146 complete
#
# BATCH Processeing started
# loss 0.56279343
# Epoch number  0 batch 147 complete
#
# BATCH Processeing started
# loss 0.43433237
# Epoch number  0 batch 148 complete
#
# BATCH Processeing started
# loss 0.6184092
# Epoch number  0 batch 149 complete
#
# BATCH Processeing started
# loss 0.7133442
# Epoch number  0 batch 150 complete
#
# BATCH Processeing started
# loss 0.50710154
# Epoch number  0 batch 151 complete
#
# BATCH Processeing started
# loss 1.2540188
# Epoch number  0 batch 152 complete
#
# BATCH Processeing started
# loss 0.513041
# Epoch number  0 batch 153 complete
#
# BATCH Processeing started
# loss 0.25972638
# Epoch number  0 batch 154 complete
#
# BATCH Processeing started
# loss 0.41482425
# Epoch number  0 batch 155 complete
#
# BATCH Processeing started
# loss 1.1596205
# Epoch number  0 batch 156 complete
#
# BATCH Processeing started
# loss 0.6162244
# Epoch number  0 batch 157 complete
#
# BATCH Processeing started
# loss 0.63382685
# Epoch number  0 batch 158 complete
#
# BATCH Processeing started
# loss 0.5683465
# Epoch number  0 batch 159 complete
#
# BATCH Processeing started
# loss 0.5194255
# Epoch number  0 batch 160 complete
#
# BATCH Processeing started
# loss 0.315486
# Epoch number  0 batch 161 complete
#
# BATCH Processeing started
# loss 0.5656363
# Epoch number  0 batch 162 complete
#
# BATCH Processeing started
# loss 0.15075609
# Epoch number  0 batch 163 complete
#
# BATCH Processeing started
# loss 0.7233918
# Epoch number  0 batch 164 complete
#
# BATCH Processeing started
# loss 0.6571307
# Epoch number  0 batch 165 complete
#
# BATCH Processeing started
# loss 0.20604233
# Epoch number  0 batch 166 complete
#
# BATCH Processeing started
# loss 0.859498
# Epoch number  0 batch 167 complete
#
# BATCH Processeing started
# loss 0.59684473
# Epoch number  0 batch 168 complete
#
# BATCH Processeing started
# loss 1.3930209
# Epoch number  0 batch 169 complete
#
# BATCH Processeing started
# loss 0.9165106
# Epoch number  0 batch 170 complete
#
# BATCH Processeing started
# loss 0.21468422
# Epoch number  0 batch 171 complete
#
# BATCH Processeing started
# loss 0.38333917
# Epoch number  0 batch 172 complete
#
# BATCH Processeing started
# loss 0.47030154
# Epoch number  0 batch 173 complete
#
# BATCH Processeing started
# loss 1.6205581
# Epoch number  0 batch 174 complete
#
# BATCH Processeing started
# loss 1.9889568
# Epoch number  0 batch 175 complete
#
# BATCH Processeing started
# loss 0.5361218
# Epoch number  0 batch 176 complete
#
# BATCH Processeing started
# loss 0.67276126
# Epoch number  0 batch 177 complete
#
# BATCH Processeing started
# loss 0.6566102
# Epoch number  0 batch 178 complete
#
# BATCH Processeing started
# loss 0.48889595
# Epoch number  0 batch 179 complete
#
# BATCH Processeing started
# loss 0.58797044
# Epoch number  0 batch 180 complete
#
# BATCH Processeing started
# loss 0.886656
# Epoch number  0 batch 181 complete
#
# BATCH Processeing started
# loss 0.54380745
# Epoch number  0 batch 182 complete
#
# BATCH Processeing started
# loss 0.5638875
# Epoch number  0 batch 183 complete
#
# BATCH Processeing started
# loss 0.46070504
# Epoch number  0 batch 184 complete
#
# BATCH Processeing started
# loss 0.7842678
# Epoch number  0 batch 185 complete
#
# BATCH Processeing started
# loss 2.9367511
# Epoch number  0 batch 186 complete
#
# BATCH Processeing started
# loss 2.0219574
# Epoch number  0 batch 187 complete
#
# BATCH Processeing started
# loss 1.0702776
# Epoch number  0 batch 188 complete
#
# BATCH Processeing started
# loss 0.5397987
# Epoch number  0 batch 189 complete
#
# BATCH Processeing started
# loss 1.4436805
# Epoch number  0 batch 190 complete
#
# BATCH Processeing started
# loss 1.3558071
# Epoch number  0 batch 191 complete
#
# BATCH Processeing started
# loss 0.19809267
# Epoch number  0 batch 192 complete
#
# BATCH Processeing started
# loss 1.193663
# Epoch number  0 batch 193 complete
#
# BATCH Processeing started
# loss 1.2791822
# Epoch number  0 batch 194 complete
#
# BATCH Processeing started
# loss 0.5956825
# Epoch number  0 batch 195 complete
#
# BATCH Processeing started
# loss 0.30851325
# Epoch number  0 batch 196 complete
#
# BATCH Processeing started
# loss 0.48017073
# Epoch number  0 batch 197 complete
#
# BATCH Processeing started
# loss 0.42924985
# Epoch number  0 batch 198 complete
#
# BATCH Processeing started
# loss 0.6536541
# Epoch number  0 batch 199 complete
#
# BATCH Processeing started
# loss 1.3002278
# Epoch number  0 batch 200 complete
#
# BATCH Processeing started
# loss 0.66926444
# Epoch number  0 batch 201 complete
#
# BATCH Processeing started
# loss 0.9063713
# Epoch number  0 batch 202 complete
#
# BATCH Processeing started
# loss 0.6486577
# Epoch number  0 batch 203 complete
#
# BATCH Processeing started
# loss 0.7027753
# Epoch number  0 batch 204 complete
#
# BATCH Processeing started
# loss 0.41333905
# Epoch number  0 batch 205 complete
#
# BATCH Processeing started
# loss 0.2843557
# Epoch number  0 batch 206 complete
#
# BATCH Processeing started
# loss 0.38294473
# Epoch number  0 batch 207 complete
#
# BATCH Processeing started
# loss 1.0265155
# Epoch number  0 batch 208 complete
#
# BATCH Processeing started
# loss 0.7583399
# Epoch number  0 batch 209 complete
#
# BATCH Processeing started
# loss 0.35439044
# Epoch number  0 batch 210 complete
#
# BATCH Processeing started
# loss 0.6268633
# Epoch number  0 batch 211 complete
#
# BATCH Processeing started
# loss 0.9581386
# Epoch number  0 batch 212 complete
#
# BATCH Processeing started
# loss 0.7105407
# Epoch number  0 batch 213 complete
#
# BATCH Processeing started
# loss 0.29992422
# Epoch number  0 batch 214 complete
#
# BATCH Processeing started
# loss 0.40144044
# Epoch number  0 batch 215 complete
#
# BATCH Processeing started
# loss 0.7386292
# Epoch number  0 batch 216 complete
#
# BATCH Processeing started
# loss 0.34848982
# Epoch number  0 batch 217 complete
#
# BATCH Processeing started
# loss 0.41323248
# Epoch number  0 batch 218 complete
#
# BATCH Processeing started
# loss 1.002363
# Epoch number  0 batch 219 complete
#
# BATCH Processeing started
# loss 0.89060926
# Epoch number  0 batch 220 complete
#
# BATCH Processeing started
# loss 0.72345346
# Epoch number  0 batch 221 complete
#
# BATCH Processeing started
# loss 0.66497076
# Epoch number  0 batch 222 complete
#
# BATCH Processeing started
# loss 0.8544626
# Epoch number  0 batch 223 complete
#
# BATCH Processeing started
# loss 0.5801404
# Epoch number  0 batch 224 complete
#
# BATCH Processeing started
# loss 0.6585733
# Epoch number  0 batch 225 complete
#
# BATCH Processeing started
# loss 0.5665446
# Epoch number  0 batch 226 complete
#
# BATCH Processeing started
# loss 0.52984476
# Epoch number  0 batch 227 complete
#
# BATCH Processeing started
# loss 1.0124562
# Epoch number  0 batch 228 complete
#
# BATCH Processeing started
# loss 0.39245754
# Epoch number  0 batch 229 complete
#
# BATCH Processeing started
# loss 0.35876375
# Epoch number  0 batch 230 complete
#
# BATCH Processeing started
# loss 0.54778147
# Epoch number  0 batch 231 complete
#
# BATCH Processeing started
# loss 0.8127748
# Epoch number  0 batch 232 complete
#
# BATCH Processeing started
# loss 1.5595688
# Epoch number  0 batch 233 complete
#
# BATCH Processeing started
# loss 0.6807485
# Epoch number  0 batch 234 complete
#
# BATCH Processeing started
# loss 1.8608986
# Epoch number  0 batch 235 complete
#
# BATCH Processeing started
# loss 0.99408925
# Epoch number  0 batch 236 complete
#
# BATCH Processeing started
# loss 0.6924717
# Epoch number  0 batch 237 complete
#
# BATCH Processeing started
# loss 1.7196159
# Epoch number  0 batch 238 complete
#
# BATCH Processeing started
# loss 1.0586395
# Epoch number  0 batch 239 complete
#
# BATCH Processeing started
# loss 1.5068974
# Epoch number  0 batch 240 complete
#
# BATCH Processeing started
# loss 0.49649525
# Epoch number  0 batch 241 complete
#
# BATCH Processeing started
# loss 0.46519384
# Epoch number  0 batch 242 complete
#
# BATCH Processeing started
# loss 0.5597452
# Epoch number  0 batch 243 complete
#
# BATCH Processeing started
# loss 0.69065773
# Epoch number  0 batch 244 complete
#
# BATCH Processeing started
# loss 0.4455533
# Epoch number  0 batch 245 complete
#
# BATCH Processeing started
# loss 0.45146483
# Epoch number  0 batch 246 complete
#
# BATCH Processeing started
# loss 0.53714865
# Epoch number  0 batch 247 complete
#
# BATCH Processeing started
# loss 0.59632885
# Epoch number  0 batch 248 complete
#
# BATCH Processeing started
# loss 0.562745
# Epoch number  0 batch 249 complete
#
# BATCH Processeing started
# loss 0.8013862
# Epoch number  0 batch 250 complete
#
# BATCH Processeing started
# loss 0.56496084
# Epoch number  0 batch 251 complete
#
# BATCH Processeing started
# loss 0.6834713
# Epoch number  0 batch 252 complete
#
# BATCH Processeing started
# loss 0.6079537
# Epoch number  0 batch 253 complete
#
# BATCH Processeing started
# loss 0.45371714
# Epoch number  0 batch 254 complete
#
# BATCH Processeing started
# loss 0.45825702
# Epoch number  0 batch 255 complete
#
# BATCH Processeing started
# loss 0.3565238
# Epoch number  0 batch 256 complete
#
# BATCH Processeing started
# loss 0.43850088
# Epoch number  0 batch 257 complete
#
# BATCH Processeing started
# loss 0.55054176
# Epoch number  0 batch 258 complete
#
# BATCH Processeing started
# loss 0.8419038
# Epoch number  0 batch 259 complete
#
# BATCH Processeing started
# loss 0.57224196
# Epoch number  0 batch 260 complete
#
# BATCH Processeing started
# loss 0.6052217
# Epoch number  0 batch 261 complete
#
# BATCH Processeing started
# loss 0.67700255
# Epoch number  0 batch 262 complete
#
# BATCH Processeing started
# loss 0.77343816
# Epoch number  0 batch 263 complete
#
# BATCH Processeing started
# loss 0.57952297
# Epoch number  0 batch 264 complete
#
# BATCH Processeing started
# loss 0.41095823
# Epoch number  0 batch 265 complete
#
# BATCH Processeing started
# loss 0.5189046
# Epoch number  0 batch 266 complete
#
# BATCH Processeing started
# loss 0.6346124
# Epoch number  0 batch 267 complete
#
# BATCH Processeing started
# loss 0.5283844
# Epoch number  0 batch 268 complete
#
# BATCH Processeing started
# loss 0.5602424
# Epoch number  0 batch 269 complete
#
# BATCH Processeing started
# loss 0.6607796
# Epoch number  0 batch 270 complete
#
# BATCH Processeing started
# loss 0.5583981
# Epoch number  0 batch 271 complete
#
# BATCH Processeing started
# loss 0.4209566
# Epoch number  0 batch 272 complete
#
# BATCH Processeing started
# loss 0.7077765
# Epoch number  0 batch 273 complete
#
# BATCH Processeing started
# loss 0.47901082
# Epoch number  0 batch 274 complete
#
# BATCH Processeing started
# loss 0.3392833
# Epoch number  0 batch 275 complete
#
# BATCH Processeing started
# loss 0.5696506
# Epoch number  0 batch 276 complete
#
# BATCH Processeing started
# loss 0.2980674
# Epoch number  0 batch 277 complete
#
# BATCH Processeing started
# loss 0.52842623
# Epoch number  0 batch 278 complete
#
# BATCH Processeing started
# loss 0.37954965
# Epoch number  0 batch 279 complete
#
# BATCH Processeing started
# loss 0.25791723
# Epoch number  0 batch 280 complete
#
# BATCH Processeing started
# loss 1.6592642
# Epoch number  0 batch 281 complete
#
# BATCH Processeing started
# loss 1.1439077
# Epoch number  0 batch 282 complete
#
# BATCH Processeing started
# loss 1.859968
# Epoch number  0 batch 283 complete
#
# BATCH Processeing started
# loss 0.6388327
# Epoch number  0 batch 284 complete
#
# BATCH Processeing started
# loss 0.59913874
# Epoch number  0 batch 285 complete
#
# BATCH Processeing started
# loss 0.36651677
# Epoch number  0 batch 286 complete
#
# BATCH Processeing started
# loss 0.79972184
# Epoch number  0 batch 287 complete
#
# BATCH Processeing started
# loss 0.5671446
# Epoch number  0 batch 288 complete
#
# BATCH Processeing started
# loss 0.87871915
# Epoch number  0 batch 289 complete
#
# BATCH Processeing started
# loss 0.63956195
# Epoch number  0 batch 290 complete
#
# BATCH Processeing started
# loss 1.2327156
# Epoch number  0 batch 291 complete
#
# BATCH Processeing started
# loss 0.33077088
# Epoch number  0 batch 292 complete
#
# BATCH Processeing started
# loss 0.2031352
# Epoch number  0 batch 293 complete
#
# BATCH Processeing started
# loss 0.31801552
# Epoch number  0 batch 294 complete
#
# BATCH Processeing started
# loss 0.36896747
# Epoch number  0 batch 295 complete
#
# BATCH Processeing started
# loss 0.366857
# Epoch number  0 batch 296 complete
#
# BATCH Processeing started
# loss 0.3653217
# Epoch number  0 batch 297 complete
#
# BATCH Processeing started
# loss 0.3935975
# Epoch number  0 batch 298 complete
#
# BATCH Processeing started
# loss 1.4572709
# Epoch number  0 batch 299 complete
#
# BATCH Processeing started
# loss 0.9773859
# Epoch number  0 batch 300 complete
#
# BATCH Processeing started
# loss 0.7496281
# Epoch number  0 batch 301 complete
#
# BATCH Processeing started
# loss 0.4449908
# Epoch number  0 batch 302 complete
#
# BATCH Processeing started
# loss 0.7860602
# Epoch number  0 batch 303 complete
#
# BATCH Processeing started
# loss 0.34897733
# Epoch number  0 batch 304 complete
#
# BATCH Processeing started
# loss 1.4947255
# Epoch number  0 batch 305 complete
#
# BATCH Processeing started
# loss 0.37821513
# Epoch number  0 batch 306 complete
#
# BATCH Processeing started
# loss 0.3969373
# Epoch number  0 batch 307 complete
#
# BATCH Processeing started
# loss 0.8583924
# Epoch number  0 batch 308 complete
#
# BATCH Processeing started
# loss 0.7370004
# Epoch number  0 batch 309 complete
#
# BATCH Processeing started
# loss 0.86243516
# Epoch number  0 batch 310 complete
#
# BATCH Processeing started
# loss 0.5266797
# Epoch number  0 batch 311 complete
#
# BATCH Processeing started
# loss 0.45907035
# Epoch number  0 batch 312 complete
#
# BATCH Processeing started
# loss 0.47093162
# Epoch number  0 batch 313 complete
#
# BATCH Processeing started
# loss 0.69585764
# Epoch number  0 batch 314 complete
#
# BATCH Processeing started
# loss 0.48985967
# Epoch number  0 batch 315 complete
#
# BATCH Processeing started
# loss 0.36984527
# Epoch number  0 batch 316 complete
#
# BATCH Processeing started
# loss 0.8748577
# Epoch number  0 batch 317 complete
#
# BATCH Processeing started
# loss 0.6450056
# Epoch number  0 batch 318 complete
#
# BATCH Processeing started
# loss 0.56259084
# Epoch number  0 batch 319 complete
#
# BATCH Processeing started
# loss 0.47208196
# Epoch number  0 batch 320 complete
#
# BATCH Processeing started
# loss 0.53517777
# Epoch number  0 batch 321 complete
#
# BATCH Processeing started
# loss 0.5351967
# Epoch number  0 batch 322 complete
#
# BATCH Processeing started
# loss 0.5287523
# Epoch number  0 batch 323 complete
#
# BATCH Processeing started
# loss 0.6494097
# Epoch number  0 batch 324 complete
#
# BATCH Processeing started
# loss 1.0418863
# Epoch number  0 batch 325 complete
#
# BATCH Processeing started
# loss 0.5775465
# Epoch number  0 batch 326 complete
#
# BATCH Processeing started
# loss 0.53466016
# Epoch number  0 batch 327 complete
#
# BATCH Processeing started
# loss 0.8980091
# Epoch number  0 batch 328 complete
#
# BATCH Processeing started
# loss 0.39165792
# Epoch number  0 batch 329 complete
#
# BATCH Processeing started
# loss 0.58935666
# Epoch number  0 batch 330 complete
#
# BATCH Processeing started
# loss 0.6955078
# Epoch number  0 batch 331 complete
#
# BATCH Processeing started
# loss 0.7013818
# Epoch number  0 batch 332 complete
#
# BATCH Processeing started
# loss 0.4829282
# Epoch number  0 batch 333 complete
#
# BATCH Processeing started
# loss 0.564214
# Epoch number  0 batch 334 complete
#
# BATCH Processeing started
# loss 0.45851445
# Epoch number  0 batch 335 complete
#
# BATCH Processeing started
# loss 0.9601992
# Epoch number  0 batch 336 complete
#
# BATCH Processeing started
# loss 0.3745926
# Epoch number  0 batch 337 complete
#
# BATCH Processeing started
# loss 0.69157314
# Epoch number  0 batch 338 complete
#
# BATCH Processeing started
# loss 0.52474433
# Epoch number  0 batch 339 complete
#
# BATCH Processeing started
# loss 0.55753773
# Epoch number  0 batch 340 complete
#
# BATCH Processeing started
# loss 0.7528071
# Epoch number  0 batch 341 complete
#
# BATCH Processeing started
# loss 1.0548503
# Epoch number  0 batch 342 complete
#
# BATCH Processeing started
# loss 0.7501788
# Epoch number  0 batch 343 complete
#
# BATCH Processeing started
# loss 0.8329857
# Epoch number  0 batch 344 complete
#
# BATCH Processeing started
# loss 0.5035189
# Epoch number  0 batch 345 complete
#
# BATCH Processeing started
# loss 0.83311796
# Epoch number  0 batch 346 complete
#
# BATCH Processeing started
# loss 0.79954547
# Epoch number  0 batch 347 complete
#
# BATCH Processeing started
# loss 0.661156
# Epoch number  0 batch 348 complete
#
# BATCH Processeing started
# loss 0.420511
# Epoch number  0 batch 349 complete
#
# BATCH Processeing started
# loss 0.9944906
# Epoch number  0 batch 350 complete
#
# BATCH Processeing started
# loss 0.27683455
# Epoch number  0 batch 351 complete
#
# BATCH Processeing started
# loss 0.33979398
# Epoch number  0 batch 352 complete
#
# BATCH Processeing started
# loss 0.8012951
# Epoch number  0 batch 353 complete
#
# BATCH Processeing started
# loss 0.9925602
# Epoch number  0 batch 354 complete
#
# BATCH Processeing started
# loss 1.1462114
# Epoch number  0 batch 355 complete
#
# BATCH Processeing started
# loss 0.9129505
# Epoch number  0 batch 356 complete
#
# BATCH Processeing started
# loss 0.27848
# Epoch number  0 batch 357 complete
#
# BATCH Processeing started
# loss 0.23484962
# Epoch number  0 batch 358 complete
#
# BATCH Processeing started
# loss 0.40681309
# Epoch number  0 batch 359 complete
#
# BATCH Processeing started
# loss 0.952773
# Epoch number  0 batch 360 complete
#
# BATCH Processeing started
# loss 0.36450374
# Epoch number  0 batch 361 complete
#
# BATCH Processeing started
# loss 0.68370473
# Epoch number  0 batch 362 complete
#
# BATCH Processeing started
# loss 0.6062093
# Epoch number  0 batch 363 complete
#
# BATCH Processeing started
# loss 0.32703355
# Epoch number  0 batch 364 complete
#
# BATCH Processeing started
# loss 0.6361974
# Epoch number  0 batch 365 complete
#
# BATCH Processeing started
# loss 0.84386605
# Epoch number  0 batch 366 complete
#
# BATCH Processeing started
# loss 0.74382514
# Epoch number  0 batch 367 complete
#
# BATCH Processeing started
# loss 0.6239327
# Epoch number  0 batch 368 complete
#
# BATCH Processeing started
# loss 0.8753192
# Epoch number  0 batch 369 complete
#
# BATCH Processeing started
# loss 1.1977805
# Epoch number  0 batch 370 complete
#
# BATCH Processeing started
# loss 1.1197019
# Epoch number  0 batch 371 complete
#
# BATCH Processeing started
# loss 0.68358415
# Epoch number  0 batch 372 complete
#
# BATCH Processeing started
# loss 0.55147094
# Epoch number  0 batch 373 complete
#
# BATCH Processeing started
# loss 0.6859242
# Epoch number  0 batch 374 complete
#
# BATCH Processeing started
# loss 0.5488598
# Epoch number  0 batch 375 complete
#
# BATCH Processeing started
# loss 1.1665574
# Epoch number  0 batch 376 complete
#
# BATCH Processeing started
# loss 0.5754387
# Epoch number  0 batch 377 complete
#
# BATCH Processeing started
# loss 0.64152116
# Epoch number  0 batch 378 complete
#
# BATCH Processeing started
# loss 0.4867843
# Epoch number  0 batch 379 complete
#
# BATCH Processeing started
# loss 0.63371927
# Epoch number  0 batch 380 complete
#
# BATCH Processeing started
# loss 0.43366152
# Epoch number  0 batch 381 complete
#
# BATCH Processeing started
# loss 0.43705958
# Epoch number  0 batch 382 complete
#
# BATCH Processeing started
# loss 0.48289055
# Epoch number  0 batch 383 complete
#
# BATCH Processeing started
# loss 0.63925505
# Epoch number  0 batch 384 complete
#
# BATCH Processeing started
# loss 0.75284076
# Epoch number  0 batch 385 complete
#
# BATCH Processeing started
# loss 0.45341015
# Epoch number  0 batch 386 complete
#
# BATCH Processeing started
# loss 0.4086923
# Epoch number  0 batch 387 complete
#
# BATCH Processeing started
# loss 0.8782056
# Epoch number  0 batch 388 complete
#
# BATCH Processeing started
# loss 0.34742326
# Epoch number  0 batch 389 complete
#
# BATCH Processeing started
# loss 0.5286157
# Epoch number  0 batch 390 complete
#
# BATCH Processeing started
# loss 0.78807354
# Epoch number  0 batch 391 complete
#
# BATCH Processeing started
# loss 0.7888023
# Epoch number  0 batch 392 complete
#
# BATCH Processeing started
# loss 0.37246078
# Epoch number  0 batch 393 complete
#
# BATCH Processeing started
# loss 0.9238204
# Epoch number  0 batch 394 complete
#
# BATCH Processeing started
# loss 0.50104773
# Epoch number  0 batch 395 complete
#
# BATCH Processeing started
# loss 1.108038
# Epoch number  0 batch 396 complete
#
# BATCH Processeing started
# loss 0.26835498
# Epoch number  0 batch 397 complete
#
# BATCH Processeing started
# loss 0.60329854
# Epoch number  0 batch 398 complete
#
# BATCH Processeing started
# loss 0.641626
# Epoch number  0 batch 399 complete
#
# BATCH Processeing started
# loss 1.0343314
# Epoch number  0 batch 400 complete
#
# BATCH Processeing started
# loss 0.7754205
# Epoch number  0 batch 401 complete
#
# BATCH Processeing started
# loss 0.8914434
# Epoch number  0 batch 402 complete
#
# BATCH Processeing started
# loss 0.73107016
# Epoch number  0 batch 403 complete
#
# BATCH Processeing started
# loss 0.51597935
# Epoch number  0 batch 404 complete
#
# BATCH Processeing started
# loss 0.5872113
# Epoch number  0 batch 405 complete
#
# BATCH Processeing started
# loss 1.1214854
# Epoch number  0 batch 406 complete
#
# BATCH Processeing started
# loss 0.85779065
# Epoch number  0 batch 407 complete
#
# BATCH Processeing started
# loss 0.71543574
# Epoch number  0 batch 408 complete
#
# BATCH Processeing started
# loss 0.41692024
# Epoch number  0 batch 409 complete
#
# BATCH Processeing started
# loss 0.9894945
# Epoch number  0 batch 410 complete
#
# BATCH Processeing started
# loss 0.5171563
# Epoch number  0 batch 411 complete
#
# BATCH Processeing started
# loss 0.5011905
# Epoch number  0 batch 412 complete
#
# BATCH Processeing started
# loss 0.3700413
# Epoch number  0 batch 413 complete
#
# BATCH Processeing started
# loss 0.4190673
# Epoch number  0 batch 414 complete
#
# BATCH Processeing started
# loss 0.55399185
# Epoch number  0 batch 415 complete
#
# BATCH Processeing started
# loss 0.23086497
# Epoch number  0 batch 416 complete
#
# BATCH Processeing started
# loss 0.4898211
# Epoch number  0 batch 417 complete
#
# BATCH Processeing started
# loss 0.4150824
# Epoch number  0 batch 418 complete
#
# BATCH Processeing started
# loss 0.3385716
# Epoch number  0 batch 419 complete
#
# BATCH Processeing started
# loss 0.5828705
# Epoch number  0 batch 420 complete
#
# BATCH Processeing started
# loss 0.2636579
# Epoch number  0 batch 421 complete
#
# BATCH Processeing started
# loss 2.342908
# Epoch number  0 batch 422 complete
#
# BATCH Processeing started
# loss 0.25544506
# Epoch number  0 batch 423 complete
#
# BATCH Processeing started
# loss 0.88078946
# Epoch number  0 batch 424 complete
#
# BATCH Processeing started
# loss 0.7276147
# Epoch number  0 batch 425 complete
#
# BATCH Processeing started
# loss 0.71920687
# Epoch number  0 batch 426 complete
#
# BATCH Processeing started
# loss 0.250292
# Epoch number  0 batch 427 complete
#
# BATCH Processeing started
# loss 0.922054
# Epoch number  0 batch 428 complete
#
# BATCH Processeing started
# loss 0.75591743
# Epoch number  0 batch 429 complete
#
# BATCH Processeing started
# loss 0.6124597
# Epoch number  0 batch 430 complete
#
# BATCH Processeing started
# loss 0.6168081
# Epoch number  0 batch 431 complete
#
# BATCH Processeing started
# loss 0.40102834
# Epoch number  0 batch 432 complete
#
# BATCH Processeing started
# loss 0.5327784
# Epoch number  0 batch 433 complete
#
# BATCH Processeing started
# loss 0.6211287
# Epoch number  0 batch 434 complete
#
# BATCH Processeing started
# loss 0.51405156
# Epoch number  0 batch 435 complete
#
# BATCH Processeing started
# loss 0.6150062
# Epoch number  0 batch 436 complete
#
# BATCH Processeing started
# loss 0.5942925
# Epoch number  0 batch 437 complete
#
# BATCH Processeing started
# loss 0.34801096
# Epoch number  0 batch 438 complete
#
# BATCH Processeing started
# loss 0.33191642
# Epoch number  0 batch 439 complete
#
# BATCH Processeing started
# loss 0.77539384
# Epoch number  0 batch 440 complete
#
# BATCH Processeing started
# loss 0.42026192
# Epoch number  0 batch 441 complete
#
# BATCH Processeing started
# loss 0.7729424
# Epoch number  0 batch 442 complete
#
# BATCH Processeing started
# loss 0.71974033
# Epoch number  0 batch 443 complete
#
# BATCH Processeing started
# loss 0.89775497
# Epoch number  0 batch 444 complete
#
# BATCH Processeing started
# loss 0.4966876
# Epoch number  0 batch 445 complete
#
# BATCH Processeing started
# loss 0.68574
# Epoch number  0 batch 446 complete
#
# BATCH Processeing started
# loss 0.5982382
# Epoch number  0 batch 447 complete
#
# BATCH Processeing started
# loss 0.4733219
# Epoch number  0 batch 448 complete
#
# BATCH Processeing started
# loss 0.4345242
# Epoch number  0 batch 449 complete
#
# BATCH Processeing started
# loss 0.8197664
# Epoch number  0 batch 450 complete
#
# BATCH Processeing started
# loss 0.48995227
# Epoch number  0 batch 451 complete
#
# BATCH Processeing started
# loss 0.39900106
# Epoch number  0 batch 452 complete
#
# BATCH Processeing started
# loss 0.89707315
# Epoch number  0 batch 453 complete
#
# BATCH Processeing started
# loss 0.5086611
# Epoch number  0 batch 454 complete
#
# BATCH Processeing started
# loss 0.45637694
# Epoch number  0 batch 455 complete
#
# BATCH Processeing started
# loss 0.62931556
# Epoch number  0 batch 456 complete
#
# BATCH Processeing started
# loss 0.5290195
# Epoch number  0 batch 457 complete
#
# BATCH Processeing started
# loss 0.67942464
# Epoch number  0 batch 458 complete
#
# BATCH Processeing started
# loss 0.8116026
# Epoch number  0 batch 459 complete
#
# BATCH Processeing started
# loss 0.8589719
# Epoch number  0 batch 460 complete
#
# BATCH Processeing started
# loss 0.47526044
# Epoch number  0 batch 461 complete
#
# BATCH Processeing started
# loss 0.62168837
# Epoch number  0 batch 462 complete
#
# BATCH Processeing started
# loss 0.61085135
# Epoch number  0 batch 463 complete
#
# BATCH Processeing started
# loss 0.58540535
# Epoch number  0 batch 464 complete
#
# BATCH Processeing started
# loss 0.44170278
# Epoch number  0 batch 465 complete
#
# BATCH Processeing started
# loss 0.47861546
# Epoch number  0 batch 466 complete
#
# BATCH Processeing started
# loss 0.3675066
# Epoch number  0 batch 467 complete
#
# BATCH Processeing started
# loss 0.39295
# Epoch number  0 batch 468 complete
#
# BATCH Processeing started
# loss 0.668718
# Epoch number  0 batch 469 complete
#
# BATCH Processeing started
# loss 0.8736887
# Epoch number  0 batch 470 complete
#
# BATCH Processeing started
# loss 0.47998938
# Epoch number  0 batch 471 complete
#
# BATCH Processeing started
# loss 0.59024936
# Epoch number  0 batch 472 complete
#
# BATCH Processeing started
# loss 0.9858751
# Epoch number  0 batch 473 complete
#
# BATCH Processeing started
# loss 1.2624304
# Epoch number  0 batch 474 complete
#
# BATCH Processeing started
# loss 0.21242769
# Epoch number  0 batch 475 complete
#
# BATCH Processeing started
# loss 0.1831328
# Epoch number  0 batch 476 complete
#
# BATCH Processeing started
# loss 0.21281807
# Epoch number  0 batch 477 complete
#
# BATCH Processeing started
# loss 0.23817441
# Epoch number  0 batch 478 complete
#
# BATCH Processeing started
# loss 0.34032628
# Epoch number  0 batch 479 complete
#
# BATCH Processeing started
# loss 0.9071687
# Epoch number  0 batch 480 complete
#
# BATCH Processeing started
# loss 1.342599
# Epoch number  0 batch 481 complete
#
# BATCH Processeing started
# loss 0.40125507
# Epoch number  0 batch 482 complete
#
# BATCH Processeing started
# loss 0.31499618
# Epoch number  0 batch 483 complete
#
# BATCH Processeing started
# loss 1.306345
# Epoch number  0 batch 484 complete
#
# BATCH Processeing started
# loss 0.3659919
# Epoch number  0 batch 485 complete
#
# BATCH Processeing started
# loss 0.667059
# Epoch number  0 batch 486 complete
#
# BATCH Processeing started
# loss 0.723941
# Epoch number  0 batch 487 complete
#
# BATCH Processeing started
# loss 0.6080903
# Epoch number  0 batch 488 complete
#
# BATCH Processeing started
# loss 0.60144585
# Epoch number  0 batch 489 complete
#
# BATCH Processeing started
# loss 0.5560638
# Epoch number  0 batch 490 complete
#
# BATCH Processeing started
# loss 0.46272868
# Epoch number  0 batch 491 complete
#
# BATCH Processeing started
# loss 0.33143848
# Epoch number  0 batch 492 complete
#
# BATCH Processeing started
# loss 0.55650055
# Epoch number  0 batch 493 complete
#
# BATCH Processeing started
# loss 0.94951075
# Epoch number  0 batch 494 complete
#
# BATCH Processeing started
# loss 0.8168785
# Epoch number  0 batch 495 complete
#
# BATCH Processeing started
# loss 0.9209077
# Epoch number  0 batch 496 complete
#
# BATCH Processeing started
# loss 0.50416005
# Epoch number  0 batch 497 complete
#
# BATCH Processeing started
# loss 0.9949584
# Epoch number  0 batch 498 complete
#
# BATCH Processeing started
# loss 0.38076386
# Epoch number  0 batch 499 complete
#
# BATCH Processeing started
# loss 0.7195345
# Epoch number  0 batch 500 complete
#
# BATCH Processeing started
# loss 0.4390189
# Epoch number  0 batch 501 complete
#
# BATCH Processeing started
# loss 0.686373
# Epoch number  0 batch 502 complete
#
# BATCH Processeing started
# loss 0.5194041
# Epoch number  0 batch 503 complete
#
# BATCH Processeing started
# loss 0.40555176
# Epoch number  0 batch 504 complete
#
# BATCH Processeing started
# loss 0.34992328
# Epoch number  0 batch 505 complete
#
# BATCH Processeing started
# loss 0.5288951
# Epoch number  0 batch 506 complete
#
# BATCH Processeing started
# loss 1.0233774
# Epoch number  0 batch 507 complete
#
# BATCH Processeing started
# loss 0.5007405
# Epoch number  0 batch 508 complete
#
# BATCH Processeing started
# loss 1.6803958
# Epoch number  0 batch 509 complete
#
# BATCH Processeing started
# loss 0.474291
# Epoch number  0 batch 510 complete
#
# BATCH Processeing started
# loss 0.62510043
# Epoch number  0 batch 511 complete
#
# BATCH Processeing started
# loss 0.47424468
# Epoch number  0 batch 512 complete
#
# BATCH Processeing started
# loss 0.5217428
# Epoch number  0 batch 513 complete
#
# BATCH Processeing started
# loss 0.6031607
# Epoch number  0 batch 514 complete
#
# BATCH Processeing started
# loss 0.4549648
# Epoch number  0 batch 515 complete
#
# BATCH Processeing started
# loss 0.2848454
# Epoch number  0 batch 516 complete
#
# BATCH Processeing started
# loss 0.42090708
# Epoch number  0 batch 517 complete
#
# BATCH Processeing started
# loss 0.15276703
# Epoch number  0 batch 518 complete
#
# BATCH Processeing started
# loss 0.23944001
# Epoch number  0 batch 519 complete
#
# BATCH Processeing started
# loss 0.12621054
# Epoch number  0 batch 520 complete
#
# BATCH Processeing started
# loss 1.231001
# Epoch number  0 batch 521 complete
#
# BATCH Processeing started
# loss 1.452879
# Epoch number  0 batch 522 complete
#
# BATCH Processeing started
# loss 1.7669723
# Epoch number  0 batch 523 complete
#
# BATCH Processeing started
# loss 0.20493665
# Epoch number  0 batch 524 complete
#
# BATCH Processeing started
# loss 0.93398046
# Epoch number  0 batch 525 complete
#
# BATCH Processeing started
# loss 0.7429839
# Epoch number  0 batch 526 complete
#
# BATCH Processeing started
# loss 0.40982705
# Epoch number  0 batch 527 complete
#
# BATCH Processeing started
# loss 0.74900377
# Epoch number  0 batch 528 complete
#
# BATCH Processeing started
# loss 0.7337161
# Epoch number  0 batch 529 complete
#
# BATCH Processeing started
# loss 0.8316436
# Epoch number  0 batch 530 complete
#
# BATCH Processeing started
# loss 0.16859606
# Epoch number  0 batch 531 complete
#
# BATCH Processeing started
# loss 0.6395796
# Epoch number  0 batch 532 complete
#
# BATCH Processeing started
# loss 0.4247579
# Epoch number  0 batch 533 complete
#
# BATCH Processeing started
# loss 0.29602814
# Epoch number  0 batch 534 complete
#
# BATCH Processeing started
# loss 0.28130895
# Epoch number  0 batch 535 complete
#
# BATCH Processeing started
# loss 0.8160013
# Epoch number  0 batch 536 complete
#
# BATCH Processeing started
# loss 0.43780953
# Epoch number  0 batch 537 complete
#
# BATCH Processeing started
# loss 0.8746365
# Epoch number  0 batch 538 complete
#
# BATCH Processeing started
# loss 0.80711854
# Epoch number  0 batch 539 complete
#
# BATCH Processeing started
# loss 0.85843027
# Epoch number  0 batch 540 complete
#
# BATCH Processeing started
# loss 0.5043186
# Epoch number  0 batch 541 complete
#
# BATCH Processeing started
# loss 0.5400489
# Epoch number  0 batch 542 complete
#
# BATCH Processeing started
# loss 0.75979686
# Epoch number  0 batch 543 complete
#
# BATCH Processeing started
# loss 0.5301932
# Epoch number  0 batch 544 complete
#
# BATCH Processeing started
# loss 0.6155906
# Epoch number  0 batch 545 complete
#
# BATCH Processeing started
# loss 0.57592535
# Epoch number  0 batch 546 complete
#
# BATCH Processeing started
# loss 1.1364698
# Epoch number  0 batch 547 complete
#
# BATCH Processeing started
# loss 0.34218162
# Epoch number  0 batch 548 complete
#
# BATCH Processeing started
# loss 0.31788388
# Epoch number  0 batch 549 complete
#
# BATCH Processeing started
# loss 0.6366854
# Epoch number  0 batch 550 complete
#
# BATCH Processeing started
# loss 0.2903505
# Epoch number  0 batch 551 complete
#
# BATCH Processeing started
# loss 1.0896937
# Epoch number  0 batch 552 complete
#
# BATCH Processeing started
# loss 0.2784464
# Epoch number  0 batch 553 complete
#
# BATCH Processeing started
# loss 1.1658777
# Epoch number  0 batch 554 complete
#
# BATCH Processeing started
# loss 1.3231963
# Epoch number  0 batch 555 complete
#
# BATCH Processeing started
# loss 0.7679261
# Epoch number  0 batch 556 complete
#
# BATCH Processeing started
# loss 0.7191249
# Epoch number  0 batch 557 complete
#
# BATCH Processeing started
# loss 0.4346262
# Epoch number  0 batch 558 complete
#
# BATCH Processeing started
# loss 0.96418273
# Epoch number  0 batch 559 complete
#
# BATCH Processeing started
# loss 0.4426269
# Epoch number  0 batch 560 complete
#
# BATCH Processeing started
# loss 0.4654397
# Epoch number  0 batch 561 complete
#
# BATCH Processeing started
# loss 0.6804398
# Epoch number  0 batch 562 complete
#
# BATCH Processeing started
# loss 0.8045454
# Epoch number  0 batch 563 complete
#
# BATCH Processeing started
# loss 0.4944934
# Epoch number  0 batch 564 complete
#
# BATCH Processeing started
# loss 0.7287141
# Epoch number  0 batch 565 complete
#
# BATCH Processeing started
# loss 0.5644459
# Epoch number  0 batch 566 complete
#
# BATCH Processeing started
# loss 0.3396562
# Epoch number  0 batch 567 complete
#
# BATCH Processeing started
# loss 0.7378341
# Epoch number  0 batch 568 complete
#
# BATCH Processeing started
# loss 0.4589347
# Epoch number  0 batch 569 complete
#
# BATCH Processeing started
# loss 0.5611765
# Epoch number  0 batch 570 complete
#
# BATCH Processeing started
# loss 0.6202221
# Epoch number  0 batch 571 complete
#
# BATCH Processeing started
# loss 2.4583912
# Epoch number  0 batch 572 complete
#
# BATCH Processeing started
# loss 0.78188527
# Epoch number  0 batch 573 complete
#
# BATCH Processeing started
# loss 0.507775
# Epoch number  0 batch 574 complete
#
# BATCH Processeing started
# loss 0.30837378
# Epoch number  0 batch 575 complete
#
# BATCH Processeing started
# loss 0.47659975
# Epoch number  0 batch 576 complete
#
# BATCH Processeing started
# loss 0.414706
# Epoch number  0 batch 577 complete
#
# BATCH Processeing started
# loss 0.64942133
# Epoch number  0 batch 578 complete
#
# BATCH Processeing started
# loss 0.7265892
# Epoch number  0 batch 579 complete
#
# BATCH Processeing started
# loss 0.459756
# Epoch number  0 batch 580 complete
#
# BATCH Processeing started
# loss 0.1879379
# Epoch number  0 batch 581 complete
#
# BATCH Processeing started
# loss 0.5824792
# Epoch number  0 batch 582 complete
#
# BATCH Processeing started
# loss 0.9748003
# Epoch number  0 batch 583 complete
#
# BATCH Processeing started
# loss 0.3857061
# Epoch number  0 batch 584 complete
#
# BATCH Processeing started
# loss 0.61939394
# Epoch number  0 batch 585 complete
#
# BATCH Processeing started
# loss 0.33372146
# Epoch number  0 batch 586 complete
#
# BATCH Processeing started
# loss 0.3019379
# Epoch number  0 batch 587 complete
#
# BATCH Processeing started
# loss 2.2838228
# Epoch number  0 batch 588 complete
#
# BATCH Processeing started
# loss 0.20448498
# Epoch number  0 batch 589 complete
#
# BATCH Processeing started
# loss 1.0462089
# Epoch number  0 batch 590 complete
#
# BATCH Processeing started
# loss 0.590467
# Epoch number  0 batch 591 complete
#
# BATCH Processeing started
# loss 0.41186413
# Epoch number  0 batch 592 complete
#
# BATCH Processeing started
# loss 0.6448436
# Epoch number  0 batch 593 complete
#
# BATCH Processeing started
# loss 0.4493189
# Epoch number  0 batch 594 complete
#
# BATCH Processeing started
# loss 0.4211077
# Epoch number  0 batch 595 complete
#
# BATCH Processeing started
# loss 0.6831691
# Epoch number  0 batch 596 complete
#
# BATCH Processeing started
# loss 0.7223066
# Epoch number  0 batch 597 complete
#
# BATCH Processeing started
# loss 0.6267181
# Epoch number  0 batch 598 complete
#
# BATCH Processeing started
# loss 0.6321645
# Epoch number  0 batch 599 complete
#
# BATCH Processeing started
# loss 0.34274787
# Epoch number  0 batch 600 complete
#
# BATCH Processeing started
# loss 0.53541934
# Epoch number  0 batch 601 complete
#
# BATCH Processeing started
# loss 0.5073656
# Epoch number  0 batch 602 complete
#
# BATCH Processeing started
# loss 0.50458264
# Epoch number  0 batch 603 complete
#
# BATCH Processeing started
# loss 0.7180716
# Epoch number  0 batch 604 complete
#
# BATCH Processeing started
# loss 0.36588436
# Epoch number  0 batch 605 complete
#
# BATCH Processeing started
# loss 0.3846554
# Epoch number  0 batch 606 complete
#
# BATCH Processeing started
# loss 0.6797078
# Epoch number  0 batch 607 complete
#
# BATCH Processeing started
# loss 0.6629896
# Epoch number  0 batch 608 complete
#
# BATCH Processeing started
# loss 0.42245722
# Epoch number  0 batch 609 complete
#
# BATCH Processeing started
# loss 0.46042594
# Epoch number  0 batch 610 complete
#
# BATCH Processeing started
# loss 0.63729584
# Epoch number  0 batch 611 complete
#
# BATCH Processeing started
# loss 1.0333226
# Epoch number  0 batch 612 complete
#
# BATCH Processeing started
# loss 0.64546734
# Epoch number  0 batch 613 complete
#
# BATCH Processeing started
# loss 0.5210496
# Epoch number  0 batch 614 complete
#
# BATCH Processeing started
# loss 0.4393247
# Epoch number  0 batch 615 complete
#
# BATCH Processeing started
# loss 0.5153276
# Epoch number  0 batch 616 complete
#
# BATCH Processeing started
# loss 0.48573455
# Epoch number  0 batch 617 complete
#
# BATCH Processeing started
# loss 0.62257844
# Epoch number  0 batch 618 complete
#
# BATCH Processeing started
# loss 0.7428111
# Epoch number  0 batch 619 complete
#
# BATCH Processeing started
# loss 0.9250377
# Epoch number  0 batch 620 complete
#
# ...
# loss 0.06778477
# Epoch number  9 batch 559 complete
#
# BATCH Processeing started
# loss 0.028085435
# Epoch number  9 batch 560 complete
#
# BATCH Processeing started
# loss 0.023927774
# Epoch number  9 batch 561 complete
#
# BATCH Processeing started
# loss 0.06483269
# Epoch number  9 batch 562 complete
#
# BATCH Processeing started
# loss 0.0024180894
# Epoch number  9 batch 563 complete
#
# BATCH Processeing started
# loss 1.1776412
# Epoch number  9 batch 564 complete
#
# BATCH Processeing started
# loss 0.011257449
# Epoch number  9 batch 565 complete
#
# BATCH Processeing started
# loss 0.0012022867
# Epoch number  9 batch 566 complete
#
# BATCH Processeing started
# loss 0.01433043
# Epoch number  9 batch 567 complete
#
# BATCH Processeing started
# loss 0.49400038
# Epoch number  9 batch 568 complete
#
# BATCH Processeing started
# loss 1.4323275
# Epoch number  9 batch 569 complete
#
# BATCH Processeing started
# loss 0.023602996
# Epoch number  9 batch 570 complete
#
# BATCH Processeing started
# loss 0.014109036
# Epoch number  9 batch 571 complete
#
# BATCH Processeing started
# loss 0.0074567357
# Epoch number  9 batch 572 complete
#
# BATCH Processeing started
# loss 0.094774924
# Epoch number  9 batch 573 complete
#
# BATCH Processeing started
# loss 0.07145241
# Epoch number  9 batch 574 complete
#
# BATCH Processeing started
# loss 1.505554
# Epoch number  9 batch 575 complete
#
# BATCH Processeing started
# loss 0.020841725
# Epoch number  9 batch 576 complete
#
# BATCH Processeing started
# loss 0.038290817
# Epoch number  9 batch 577 complete
#
# BATCH Processeing started
# loss 0.03438061
# Epoch number  9 batch 578 complete
#
# BATCH Processeing started
# loss 0.19973572
# Epoch number  9 batch 579 complete
#
# BATCH Processeing started
# loss 0.7324334
# Epoch number  9 batch 580 complete
#
# BATCH Processeing started
# loss 0.23747341
# Epoch number  9 batch 581 complete
#
# BATCH Processeing started
# loss 0.00045785058
# Epoch number  9 batch 582 complete
#
# BATCH Processeing started
# loss 0.3560999
# Epoch number  9 batch 583 complete
#
# BATCH Processeing started
# loss 0.0045783734
# Epoch number  9 batch 584 complete
#
# BATCH Processeing started
# loss 0.06812137
# Epoch number  9 batch 585 complete
#
# BATCH Processeing started
# loss 0.19209196
# Epoch number  9 batch 586 complete
#
# BATCH Processeing started
# loss 0.88702184
# Epoch number  9 batch 587 complete
#
# BATCH Processeing started
# loss 5.2000018e-05
# Epoch number  9 batch 588 complete
#
# BATCH Processeing started
# loss 0.1308963
# Epoch number  9 batch 589 complete
#
# BATCH Processeing started
# loss 0.02416331
# Epoch number  9 batch 590 complete
#
# BATCH Processeing started
# loss 0.054356985
# Epoch number  9 batch 591 complete
#
# BATCH Processeing started
# loss 0.09837484
# Epoch number  9 batch 592 complete
#
# BATCH Processeing started
# loss 0.14119376
# Epoch number  9 batch 593 complete
#
# BATCH Processeing started
# loss 0.5184384
# Epoch number  9 batch 594 complete
#
# BATCH Processeing started
# loss 0.055223364
# Epoch number  9 batch 595 complete
#
# BATCH Processeing started
# loss 0.17349438
# Epoch number  9 batch 596 complete
#
# BATCH Processeing started
# loss 0.0021513153
# Epoch number  9 batch 597 complete
#
# BATCH Processeing started
# loss 1.2856938
# Epoch number  9 batch 598 complete
#
# BATCH Processeing started
# loss 0.027793
# Epoch number  9 batch 599 complete
#
# BATCH Processeing started
# loss 0.42659944
# Epoch number  9 batch 600 complete
#
# BATCH Processeing started
# loss 0.0022934908
# Epoch number  9 batch 601 complete
#
# BATCH Processeing started
# loss 0.14145556
# Epoch number  9 batch 602 complete
#
# BATCH Processeing started
# loss 0.112177216
# Epoch number  9 batch 603 complete
#
# BATCH Processeing started
# loss 0.28298745
# Epoch number  9 batch 604 complete
#
# BATCH Processeing started
# loss 0.12034036
# Epoch number  9 batch 605 complete
#
# BATCH Processeing started
# loss 0.035334907
# Epoch number  9 batch 606 complete
#
# BATCH Processeing started
# loss 0.030588686
# Epoch number  9 batch 607 complete
#
# BATCH Processeing started
# loss 0.16585283
# Epoch number  9 batch 608 complete
#
# BATCH Processeing started
# loss 0.23087183
# Epoch number  9 batch 609 complete
#
# BATCH Processeing started
# loss 0.027123088
# Epoch number  9 batch 610 complete
#
# BATCH Processeing started
# loss 0.39987344
# Epoch number  9 batch 611 complete
#
# BATCH Processeing started
# loss 0.13267906
# Epoch number  9 batch 612 complete
#
# BATCH Processeing started
# loss 0.08171187
# Epoch number  9 batch 613 complete
#
# BATCH Processeing started
# loss 0.19870825
# Epoch number  9 batch 614 complete
#
# BATCH Processeing started
# loss 0.050952107
# Epoch number  9 batch 615 complete
#
# BATCH Processeing started
# loss 0.08496153
# Epoch number  9 batch 616 complete
#
# BATCH Processeing started
# loss 0.08143112
# Epoch number  9 batch 617 complete
#
# BATCH Processeing started
# loss 0.19874695
# Epoch number  9 batch 618 complete
#
# BATCH Processeing started
# loss 0.24753992
# Epoch number  9 batch 619 complete
#
# BATCH Processeing started
# loss 0.061532207
# Epoch number  9 batch 620 complete
#
# BATCH Processeing started
# loss 0.08568702
# Epoch number  9 batch 621 complete
#
# BATCH Processeing started
# loss 0.050203063
# Epoch number  9 batch 622 complete
#
# BATCH Processeing started
# loss 0.1033715
# Epoch number  9 batch 623 complete
#
# BATCH Processeing started
# loss 0.084855594
# Epoch number  9 batch 624 complete
#
# BATCH Processeing started
# loss 0.10141762
# Epoch number  9 batch 625 complete
#
# BATCH Processeing started
# loss 0.06049613
# Epoch number  9 batch 626 complete
#
# BATCH Processeing started
# loss 0.019437138
# Epoch number  9 batch 627 complete
#
# BATCH Processeing started
# loss 0.012090404
# Epoch number  9 batch 628 complete
#
# BATCH Processeing started
# loss 0.09243764
# Epoch number  9 batch 629 complete
#
# BATCH Processeing started
# loss 0.027242523
# Epoch number  9 batch 630 complete
#
# BATCH Processeing started
# loss 0.035400905
# Epoch number  9 batch 631 complete
#
# BATCH Processeing started
# loss 0.0524531
# Epoch number  9 batch 632 complete
#
# BATCH Processeing started
# loss 0.687311
# Epoch number  9 batch 633 complete
#
# BATCH Processeing started
# loss 0.3962534
# Epoch number  9 batch 634 complete
#
# BATCH Processeing started
# loss 0.19109967
# Epoch number  9 batch 635 complete
#
# BATCH Processeing started
# loss 0.0016012834
# Epoch number  9 batch 636 complete
#
# BATCH Processeing started
# loss 0.12676476
# Epoch number  9 batch 637 complete
#
# BATCH Processeing started
# loss 0.07344293
# Epoch number  9 batch 638 complete
#
# BATCH Processeing started
# loss 0.13982984
# Epoch number  9 batch 639 complete
#
# BATCH Processeing started
# loss 0.54375577
# Epoch number  9 batch 640 complete
#
# BATCH Processeing started
# loss 0.054460842
# Epoch number  9 batch 641 complete
#
# BATCH Processeing started
# loss 0.31723148
# Epoch number  9 batch 642 complete
#
# BATCH Processeing started
# loss 0.0058383285
# Epoch number  9 batch 643 complete
#
# BATCH Processeing started
# loss 0.005005865
# Epoch number  9 batch 644 complete
#
# BATCH Processeing started
# loss 0.013233567
# Epoch number  9 batch 645 complete
#
# BATCH Processeing started
# loss 0.36152086
# Epoch number  9 batch 646 complete
#
# BATCH Processeing started
# loss 0.09381857
# Epoch number  9 batch 647 complete
#
# BATCH Processeing started
# loss 0.13322613
# Epoch number  9 batch 648 complete
#
# BATCH Processeing started
# loss 0.071059
# Epoch number  9 batch 649 complete
#
# BATCH Processeing started
# loss 0.028283546
# Epoch number  9 batch 650 complete
#
# BATCH Processeing started
# loss 0.02112772
# Epoch number  9 batch 651 complete
#
# BATCH Processeing started
# loss 0.07459432
# Epoch number  9 batch 652 complete
#
# BATCH Processeing started
# loss 0.020106468
# Epoch number  9 batch 653 complete
#
# BATCH Processeing started
# loss 0.26131725
# Epoch number  9 batch 654 complete
#
# BATCH Processeing started
# loss 0.0066077663
# Epoch number  9 batch 655 complete
#
# BATCH Processeing started
# loss 0.079139635
# Epoch number  9 batch 656 complete
#
# BATCH Processeing started
# loss 0.8922923
# Epoch number  9 batch 657 complete
#
# BATCH Processeing started
# loss 0.22965927
# Epoch number  9 batch 658 complete
#
# BATCH Processeing started
# loss 0.38323897
# Epoch number  9 batch 659 complete
#
# BATCH Processeing started
# loss 0.2813827
# Epoch number  9 batch 660 complete
#
# BATCH Processeing started
# loss 0.06599978
# Epoch number  9 batch 661 complete
#
# BATCH Processeing started
# loss 0.30037558
# Epoch number  9 batch 662 complete
#
# BATCH Processeing started
# loss 0.028096568
# Epoch number  9 batch 663 complete
#
# BATCH Processeing started
# loss 0.001887495
# Epoch number  9 batch 664 complete
#
# BATCH Processeing started
# loss 0.852564
# Epoch number  9 batch 665 complete
#
# BATCH Processeing started
# loss 0.005102778
# Epoch number  9 batch 666 complete
#
# BATCH Processeing started
# loss 0.045742236
# Epoch number  9 batch 667 complete
#
# BATCH Processeing started
# loss 0.36005205
# Epoch number  9 batch 668 complete
#
# BATCH Processeing started
# loss 0.5538937
# Epoch number  9 batch 669 complete
#
# BATCH Processeing started
# loss 0.42288828
# Epoch number  9 batch 670 complete
#
# BATCH Processeing started
# loss 0.25567588
# Epoch number  9 batch 671 complete
#
# BATCH Processeing started
# loss 0.014472867
# Epoch number  9 batch 672 complete
#
# BATCH Processeing started
# loss 0.17944469
# Epoch number  9 batch 673 complete
#
# BATCH Processeing started
# loss 0.046313826
# Epoch number  9 batch 674 complete
#
# BATCH Processeing started
# loss 0.020939037
# Epoch number  9 batch 675 complete
#
# BATCH Processeing started
# loss 0.09376051
# Epoch number  9 batch 676 complete
#
# BATCH Processeing started
# loss 0.0128988
# Epoch number  9 batch 677 complete
#
# BATCH Processeing started
# loss 0.42289034
# Epoch number  9 batch 678 complete
#
# BATCH Processeing started
# loss 0.83665884
# Epoch number  9 batch 679 complete
#
# BATCH Processeing started
# loss 0.049645245
# Epoch number  9 batch 680 complete
#
# BATCH Processeing started
# loss 0.3197242
# Epoch number  9 batch 681 complete
#
# BATCH Processeing started
# loss 0.10630097
# Epoch number  9 batch 682 complete
#
# BATCH Processeing started
# loss 0.009290461
# Epoch number  9 batch 683 complete
#
# BATCH Processeing started
# loss 0.013177519
# Epoch number  9 batch 684 complete
#
# BATCH Processeing started
# loss 0.19636855
# Epoch number  9 batch 685 complete
#
# BATCH Processeing started
# loss 0.3821801
# Epoch number  9 batch 686 complete
#
# BATCH Processeing started
# loss 0.022014942
# Epoch number  9 batch 687 complete
#
# BATCH Processeing started
# loss 0.09839583
# Epoch number  9 batch 688 complete
#
# BATCH Processeing started
# loss 0.13633099
# Epoch number  9 batch 689 complete
#
# BATCH Processeing started
# loss 0.055566538
# Epoch number  9 batch 690 complete
#
# BATCH Processeing started
# loss 0.037816785
# Epoch number  9 batch 691 complete
#
# BATCH Processeing started
# loss 0.123154685
# Epoch number  9 batch 692 complete
#
# BATCH Processeing started
# loss 0.29809672
# Epoch number  9 batch 693 complete
#
# BATCH Processeing started
# loss 2.1146722
# Epoch number  9 batch 694 complete
#
# BATCH Processeing started
# loss 0.3244332
# Epoch number  9 batch 695 complete
#
# BATCH Processeing started
# loss 0.057441466
# Epoch number  9 batch 696 complete
#
# BATCH Processeing started
# loss 0.045119118
# Epoch number  9 batch 697 complete
#
# BATCH Processeing started
# loss 0.34071186
# Epoch number  9 batch 698 complete
#
# BATCH Processeing started
# loss 0.3214205
# Epoch number  9 batch 699 complete
#
# BATCH Processeing started
# loss 0.024090646
# Epoch number  9 batch 700 complete
#
# BATCH Processeing started
# loss 0.18898481
# Epoch number  9 batch 701 complete
#
# BATCH Processeing started
# loss 0.012409401
# Epoch number  9 batch 702 complete
#
# BATCH Processeing started
# loss 1.0445234
# Epoch number  9 batch 703 complete
#
# BATCH Processeing started
# loss 0.021781176
# Epoch number  9 batch 704 complete
#
# BATCH Processeing started
# loss 0.3552849
# Epoch number  9 batch 705 complete
#
# BATCH Processeing started
# loss 0.16024898
# Epoch number  9 batch 706 complete
#
# BATCH Processeing started
# loss 0.088827886
# Epoch number  9 batch 707 complete
#
# BATCH Processeing started
# loss 0.12000747
# Epoch number  9 batch 708 complete
#
# BATCH Processeing started
# loss 0.2091037
# Epoch number  9 batch 709 complete
#
# BATCH Processeing started
# loss 0.090886444
# Epoch number  9 batch 710 complete
#
# BATCH Processeing started
# loss 0.00607962
# Epoch number  9 batch 711 complete
#
# BATCH Processeing started
# loss 0.037914418
# Epoch number  9 batch 712 complete
#
# BATCH Processeing started
# loss 0.24531522
# Epoch number  9 batch 713 complete
#
# BATCH Processeing started
# loss 0.31808168
# Epoch number  9 batch 714 complete
#
# BATCH Processeing started
# loss 0.49138576
# Epoch number  9 batch 715 complete
#
# BATCH Processeing started
# loss 0.005342181
# Epoch number  9 batch 716 complete
#
# BATCH Processeing started
# loss 0.024289578
# Epoch number  9 batch 717 complete
#
# BATCH Processeing started
# loss 0.044965897
# Epoch number  9 batch 718 complete
#
# BATCH Processeing started
# loss 0.023406606
# Epoch number  9 batch 719 complete
#
# BATCH Processeing started
# loss 0.00019642974
# Epoch number  9 batch 720 complete
#
# BATCH Processeing started
# loss 0.0975229
# Epoch number  9 batch 721 complete
#
# BATCH Processeing started
# loss 0.013812328
# Epoch number  9 batch 722 complete
#
# BATCH Processeing started
# loss 0.0027981533
# Epoch number  9 batch 723 complete
#
# BATCH Processeing started
# loss 0.026975896
# Epoch number  9 batch 724 complete
#
# BATCH Processeing started
# loss 0.004783638
# Epoch number  9 batch 725 complete
#
# BATCH Processeing started
# loss 0.23417012
# Epoch number  9 batch 726 complete
#
# BATCH Processeing started
# loss 6.34241e-05
# Epoch number  9 batch 727 complete
#
# BATCH Processeing started
# loss 0.0095744375
# Epoch number  9 batch 728 complete
#
# BATCH Processeing started
# loss 0.024083395
# Epoch number  9 batch 729 complete
#
# BATCH Processeing started
# loss 0.0039095576
# Epoch number  9 batch 730 complete
#
# BATCH Processeing started
# loss 0.0181668
# Epoch number  9 batch 731 complete
#
# BATCH Processeing started
# loss 0.021012383
# Epoch number  9 batch 732 complete
#
# BATCH Processeing started
# loss 7.16723e-05
# Epoch number  9 batch 733 complete
#
# BATCH Processeing started
# loss 0.0006799183
# Epoch number  9 batch 734 complete
#
# BATCH Processeing started
# loss 0.0004670932
# Epoch number  9 batch 735 complete
#
# BATCH Processeing started
# loss 0.0009085719
# Epoch number  9 batch 736 complete
#
# BATCH Processeing started
# loss 0.0038951826
# Epoch number  9 batch 737 complete
#
# BATCH Processeing started
# loss 0.0031033978
# Epoch number  9 batch 738 complete
#
# BATCH Processeing started
# loss 0.0011774466
# Epoch number  9 batch 739 complete
#
# BATCH Processeing started
# loss 0.01524625
# Epoch number  9 batch 740 complete
#
# BATCH Processeing started
# loss 0.0006903595
# Epoch number  9 batch 741 complete
#
# BATCH Processeing started
# loss 0.00014985882
# Epoch number  9 batch 742 complete
#
# BATCH Processeing started
# loss 3.8532948e-05
# Epoch number  9 batch 743 complete
#
# BATCH Processeing started
# loss 0.004956382
# Epoch number  9 batch 744 complete
#
# BATCH Processeing started
# loss 0.0011688571
# Epoch number  9 batch 745 complete
#
# BATCH Processeing started
# loss 0.007567303
# Epoch number  9 batch 746 complete
#
# BATCH Processeing started
# loss 3.5542314e-05
# Epoch number  9 batch 747 complete
#
# BATCH Processeing started
# loss 0.0040962915
# Epoch number  9 batch 748 complete
#
# BATCH Processeing started
# loss 0.00014693868
# Epoch number  9 batch 749 complete
#
# BATCH Processeing started
# loss 7.271621e-06
# Epoch number  9 batch 750 complete
#
# BATCH Processeing started
# loss 0.001598219
# Epoch number  9 batch 751 complete
#
# BATCH Processeing started
# loss 0.008006519
# Epoch number  9 batch 752 complete
#
# BATCH Processeing started
# loss 0.0003300348
# Epoch number  9 batch 753 complete
#
# BATCH Processeing started
# loss 0.0041958974
# Epoch number  9 batch 754 complete
#
# BATCH Processeing started
# loss 0.0011449546
# Epoch number  9 batch 755 complete
#
# BATCH Processeing started
# loss 0.00020204627
# Epoch number  9 batch 756 complete
#
# BATCH Processeing started
# loss 5.125993e-07
# Epoch number  9 batch 757 complete
#
# BATCH Processeing started
# loss 0.003647367
# Epoch number  9 batch 758 complete
#
# BATCH Processeing started
# loss 7.927115e-06
# Epoch number  9 batch 759 complete
#
# BATCH Processeing started
# loss 1.1920928e-08
# Epoch number  9 batch 760 complete
#
# BATCH Processeing started
# loss 1.6689287e-07
# Epoch number  9 batch 761 complete
#
# ---------------------------Training Over---------------------------
